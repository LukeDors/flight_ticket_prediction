# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Clean_Dataset.csv')
df=df.drop('Unnamed: 0',axis=1)

# %%
df[df['flight'] == '6E-5175']
# Out:
#       airline   flight source_city departure_time stops arrival_time  \
# 9990   Indigo  6E-5175       Delhi        Morning  zero    Afternoon
# 10120  Indigo  6E-5175       Delhi        Morning  zero    Afternoon
# 10242  Indigo  6E-5175       Delhi        Morning  zero    Afternoon
# 10403  Indigo  6E-5175       Delhi        Morning  zero    Afternoon
# 10581  Indigo  6E-5175       Delhi        Morning  zero    Afternoon
# ...       ...      ...         ...            ...   ...          ...
# 41692  Indigo  6E-5175       Delhi        Morning   one      Evening
# 41858  Indigo  6E-5175       Delhi        Morning   one    Afternoon
# 42026  Indigo  6E-5175       Delhi        Morning   one    Afternoon
# 42029  Indigo  6E-5175       Delhi        Morning   one      Evening
# 42203  Indigo  6E-5175       Delhi        Morning   one    Afternoon
#
#       destination_city    class  duration  days_left  price
# 9990         Bangalore  Economy      2.92          1   7425
# ...
